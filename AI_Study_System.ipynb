# %% [markdown]
# # 🎓 Premium AI Study System (Web App)
#
# We have completely rebuilt the application from scratch using **Gradio** for an incredibly robust, premium, and beautiful interface. It handles web-based Voice Recording natively without the complex glitches of Jupyter widgets!
#
# Run the cell below to launch the App. It will automatically install `gradio` if needed and open an interactive window right here!

# %%
import sys
import subprocess

# 1. Ensure Gradio is installed
try:
    import gradio
    print("✅ Gradio is already installed!")
except ImportError:
    print("📦 Installing Gradio... This will take a moment.")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "gradio"])
    print("✅ Gradio installed!")


# 2. Launch the premium web app natively
# You can also access it on http://localhost:7860 using your browser
# %run app.py
# Out:
# ✅ Gradio is already installed!
# Checking dependencies...
# DEBUG: Gradio New Format detected: True
# ERROR:    [Errno 10048] error while attempting to bind on address ('0.0.0.0', 7860): [winerror 10048] only one usage of each socket address (protocol/network address/port) is normally permitted
# ERROR:    [Errno 10048] error while attempting to bind on address ('0.0.0.0', 7861): [winerror 10048] only one usage of each socket address (protocol/network address/port) is normally permitted
# * Running on local URL:  http://0.0.0.0:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Exception in callback _ProactorBasePipeTransport._call_connection_lost(None)
# handle: <Handle _ProactorBasePipeTransport._call_connection_lost(None)>
# Traceback (most recent call last):
# ...
